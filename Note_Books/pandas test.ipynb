# %%
import pandas as pd

# %%
data_frame = pd.read_excel("d:/Users/1443/Downloads/CFMS_Recon_25-26.xlsx")

# %%
working = data_frame.copy()

# %%
working[working["HOA"]=="3451000900020010012VN"]
# Out:
#             MNTH                    HOA FLAG   AMOUNT
# 0     2025-04-01  3451000900020010012VN    P  18900.0
# 2724  2025-08-01  3451000900020010012VN    P  18000.0
# 8635  2026-03-01  3451000900020010012VN    P  14800.0
# 19186 2025-05-01  3451000900020010012VN    P  18900.0
# 25098 2025-12-01  3451000900020010012VN    P  15080.0
# 27363 2025-06-01  3451000900020010012VN    P  19000.0
# 28647 2025-09-01  3451000900020010012VN    P  18600.0
# 42659 2026-01-01  3451000900020010012VN    P  14800.0
# 46463 2025-07-01  3451000900020010012VN    P  19000.0
# 49430 2025-10-01  3451000900020010012VN    P  15600.0
# 61368 2026-02-01  3451000900020010012VN    P  14800.0
# 67179 2025-11-01  3451000900020010012VN    P  15600.0
